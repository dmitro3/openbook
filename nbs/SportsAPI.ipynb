# %%
import requests
import json
import pandas as pd

# %%
res = requests.get('https://api.the-odds-api.com/v4/sports/upcoming/odds/?regions=uk&markets=h2h&apiKey=7e0b63c2f85c232696de2ed96aea576a')

# %%
pd.DataFrame(json.loads(res.text))
# Out:
#                                   id               sport_key      sport_title  \
# 0   273d8efb3fcf7ac3ff01e4e5d4daeae5            baseball_mlb              MLB
# 1   3fc82c97f919f8f67699065f4db186b4            baseball_mlb              MLB
# 2   05b1f86bcc625f0d8f1c89bafd19d58d            baseball_mlb              MLB
# 3   5937c33f984e2ec456460dd4631e4bcb            baseball_mlb              MLB
# 4   1425be1b312177a22777aa7becec71bd            baseball_mlb              MLB
# 5   cf03fb4c6d5891ec37004aefb59acf71            baseball_mlb              MLB
# 6   350612a7ce7729f8c60e5beacccf1770            baseball_mlb              MLB
# 7   3ec9a065906d726a771ff328af031d0d            baseball_mlb              MLB
# 8   4a55102c37b51a5523a628ccf9bd7e89           icehockey_nhl              NHL
# 9   724de35b2eb869a162782e18f48d2cef            baseball_mlb              MLB
# 10  163ce2601c07ea4b2813788b12adf013            baseball_mlb              MLB
# ...
